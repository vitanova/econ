# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

def w(lamda):
    return lamda/(np.exp(lamda)-1)
grid=np.linspace(0.1, 0.8, 100)
fig, ax=plt.subplots()
ax.plot(grid, w(grid), lw=2, alpha=0.6, label='wage')
ax.legend()
plt.show()
